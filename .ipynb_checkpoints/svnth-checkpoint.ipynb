# %% [markdown]
# # PLotting

# %%
import pandas as pd

# %%
df=pd.read_json('data.json')
df
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.4
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 169 entries, 0 to 168
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  169 non-null    int64
#  1   Pulse     169 non-null    int64
#  2   Maxpulse  169 non-null    int64
#  3   Calories  164 non-null    float64
# dtypes: float64(1), int64(3)
# memory usage: 6.6 KB

# %%
df.dropna(inplace=True)

# %%
df.drop_duplicates(inplace=True)

# %%
df.corr()
# Out:
#           Duration     Pulse  Maxpulse  Calories
# Duration  1.000000 -0.167260  0.000074  0.922965
# Pulse    -0.167260  1.000000  0.785348  0.016282
# Maxpulse  0.000074  0.785348  1.000000  0.196412
# Calories  0.922965  0.016282  0.196412  1.000000

# %%
import matplotlib.pyplot as plt

# %%
df.plot()
# Out:
# <AxesSubplot: >

# %%
df.plot(kind="scatter",x="Duration",y="Calories")
plt.show()

# %% [markdown]
# # Plot between Duration And Calories also show that there is a good relationship between both .. as given by the corr() as 0.92134.

# %%
# Lets make a plot between the bad corelated columns...

# %%
df.plot(kind="scatter",x="Duration",y="Maxpulse")
plt.show()

# %% [markdown]
# # Histogram

# %%
df["Duration"].plot(kind="hist")
plt.show()
