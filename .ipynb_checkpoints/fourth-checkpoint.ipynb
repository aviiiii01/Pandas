# %%
import pandas as pd

# %%
df=pd.read_csv('indian_universities.csv')
df
# Out:
#                                 vteEducation in India  \
# 0                               Ministry of Education
# 1   Education by state Andhra Pradesh Arunachal Pr...
# 2                                  Education by state
# 3                                   Education by city
# 4                           Multi-location institutes
# 5                                        Universities
# 6                                             Leagues
# 7                                                Acts
# 8                                          Commission
# 9                               Entrance examinations
# 10  Higher education in IndiaRegulating organisati...
# 11                          Higher education in India
# 12                           Regulating organisations
# 13                              Professional councils
# 14                                Institutions (list)
# 15                  Institutes of National Importance
# ...

# %%
df.shape
# Out:
# (32, 2)

# %%
df.loc[[30,31]]
# Out:
#                vteEducation in India  \
# 30                      Other topics
# 31  Templates  Category  WikiProject
#
#                               vteEducation in India.1
# 30  All India Secondary School Examination Board e...
# 31                   Templates  Category  WikiProject

# %%
df.to_string()
# Out:
# '                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     
# ...

# %%
pd.options.display.max_rows
# Out:
# 9999

# %%
pd.options.display.max_rows = 9999

# %%
dfj=pd.read_json('data.json')

# %%
dfj
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.5
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112       NaN
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %%
dfj.head(10)
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0
# 5        60    102       127     300.5
# 6        60    110       136     374.0
# 7        45    104       134     253.3
# 8        30    109       133     195.1
# 9        60     98       124     269.0

# %%
df.tail()
# Out:
#                vteEducation in India  \
# 27                       By location
# 28                           By type
# 29                          By state
# 30                      Other topics
# 31  Templates  Category  WikiProject
#
#                               vteEducation in India.1
# 27  Bangalore Chennai Gurgaon Hisar Hyderabad Jams...
# 28  Railway Schools in India Delhi Public School l...
# 29                              Maharashtra Rajasthan
# 30  All India Secondary School Examination Board e...
# 31                   Templates  Category  WikiProject

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 2 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   vteEducation in India    32 non-null     object
#  1   vteEducation in India.1  32 non-null     object
# dtypes: object(2)
# memory usage: 644.0+ bytes

# %%
dfj.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 169 entries, 0 to 168
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  169 non-null    int64
#  1   Pulse     169 non-null    int64
#  2   Maxpulse  169 non-null    int64
#  3   Calories  164 non-null    float64
# dtypes: float64(1), int64(3)
# memory usage: 6.6 KB
